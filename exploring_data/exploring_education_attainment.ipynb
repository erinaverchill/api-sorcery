# %%
# %matplotlib notebook
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# filepaths
edattain_income = "../Resources/ca-educational-attainment-personal-income-2008-2014.csv"

# %%
#dataframes
edattain_income_df = pd.read_csv(edattain_income, encoding="utf-8")


edattain_income_df['Year'].value_counts()
# Out:
# 01/01/2011 12:00:00 AM    155
# 01/01/2009 12:00:00 AM    153
# 01/01/2010 12:00:00 AM    153
# 01/01/2012 12:00:00 AM    151
# 01/01/2014 12:00:00 AM    150
# 01/01/2013 12:00:00 AM    149
# 01/01/2008 12:00:00 AM    149
# Name: Year, dtype: int64

# %%
#clean out age

#no age filter
#over_17 = edattain_income_df

#over 17 data
over_17 = edattain_income_df[edattain_income_df.Age != '00 to 17']

# 18 to 64
#over_17 = edattain_income_df.loc[edattain_income_df['Age'] == '18 to 64']

# 65 and over
#over_17 = edattain_income_df.loc[edattain_income_df['Age'] == '65 to 80+']

over_17['Age'].value_counts()

#set value for what year to get data from
year = '01/01/2014 12:00:00 AM'

# %%
# create list of no high school for each personal income
no_hs = []
no_income_2014 = over_17.loc[(over_17['Personal Income'] == 'No Income') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == year) ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == year) ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$10,000 to $14,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == year) ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$15,000 to $24,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == year) ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$25,000 to $34,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == year) ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$35,000 to $49,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == year) ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$50,000 to $74,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == year) ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$75,000 and over') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == year) ]
no_hs.append(no_income_2014['Population Count'].sum())


no_hs
# Out:
# [1204529.0,
#  597039.0,
#  664607.0,
#  875498.0,
#  464564.0,
#  260579.0,
#  132516.0,
#  58945.0]

# %%
#create a list of high school education by income
hs = []
no_income_2014 = over_17.loc[(over_17['Personal Income'] == 'No Income') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == year) ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == year) ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$10,000 to $14,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == year) ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$15,000 to $24,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == year) ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$25,000 to $34,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == year) ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$35,000 to $49,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == year) ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$50,000 to $74,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == year) ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$75,000 and over') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == year) ]
hs.append(no_income_2014['Population Count'].sum())


hs
# Out:
# [1161873.0,
#  626499.0,
#  692661.0,
#  1252377.0,
#  929218.0,
#  782804.0,
#  525517.0,
#  323192.0]

# %%
year#list of some college by income
some_col = []
no_income_2014 = over_17.loc[(over_17['Personal Income'] == 'No Income') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == year) ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == year) ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$10,000 to $14,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == year) ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$15,000 to $24,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == year) ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$25,000 to $34,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == year) ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$35,000 to $49,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == year) ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$50,000 to $74,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == year) ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$75,000 and over') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == year) ]
some_col.append(no_income_2014['Population Count'].sum())


some_col
# Out:
# [985011.0,
#  810641.0,
#  798596.0,
#  1345257.0,
#  1091642.0,
#  1112421.0,
#  883826.0,
#  748103.0]

# %%
#create list of bachelors degree by income
bach = []
no_income_2014 = over_17.loc[(over_17['Personal Income'] == 'No Income') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == year) ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == year) ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$10,000 to $14,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == year) ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$15,000 to $24,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == year) ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$25,000 to $34,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == year) ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$35,000 to $49,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == year) ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$50,000 to $74,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == year) ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$75,000 and over') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == year) ]
bach.append(no_income_2014['Population Count'].sum())


bach
# Out:
# [575491.0,
#  326020.0,
#  452449.0,
#  773684.0,
#  693884.0,
#  1122791.0,
#  1594681.0,
#  2986698.0]

# %%
#create A bar graph based off model found on https://matplotlib.org/index.html

labels = ['No Income', '$5,000 to $9,999', '$10,000 to $14,999','$15,000 to $24,999',
          '$25,000 to $34,999', '$35,000 to $49,999', '$50,000 to $74,999', '$75,000 and Over']


x = np.arange(len(labels))  # the label locations
width = 0.40  # the width of the bars


fig, ax = plt.subplots()
rects1 = ax.bar(x - .3, no_hs, .2, label='No High School Diploma')
rects2 = ax.bar(x - .1, hs, .2, label='High School or Equivalent')
rects3 = ax.bar(x + .1, some_col, .2, label='Some College')
rects4 = ax.bar(x + .3, bach, .2, label="Bachelor's Degree or Higher")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Population')
ax.set_title('Population of CA by Education and Income in 2014 Over 17 years old')
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize = 'xx-small')


ax.legend(loc='best', fontsize='xx-small')
plt.xticks(rotation=30)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', rotation = '90',fontsize='xx-small')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
plt.ylim(0, 4000000)

fig.tight_layout()
fig.savefig("output_education_attainment/education_and_income_2014_over17")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# what percent of bachelors degree are making 75,0000 and over compared to not having bachelors.
per_75_over = round((bach[7]/(sum(bach)))*100,2)
print(f"{per_75_over}% of people in CA with a Bachelors Degree are making over $75,000")


#what percent is making nothing for bachelors compared to not bachelors
per_no_inc = round((bach[0]/(sum(bach)))*100,2)
print(f"{per_no_inc}% of people in CA with a Bachelors Degree have no income")
#what percent do not have a degree and are making no income and over 75,000
tot_pop = sum(some_col) + sum(hs) + sum(no_hs)
tot_pop_75over = some_col[7] + hs[7] + no_hs[7]
tot_pop_per_75over = round((tot_pop_75over/tot_pop)*100,2)
tot_pop_noinc = some_col[0] + hs[0] + no_hs[0]
tot_pop_per_noinc = round((tot_pop_noinc/tot_pop)*100,2)
print(f"{tot_pop_per_75over}% of people in CA without a Bachelor's Degree are making over $75,000")
print(f"{tot_pop_per_noinc}% of people in CA without a Bachelor's Degree are making over $75,000")
# Out:
# 35.03% of people in CA with a Bachelors Degree are making over $75,000
# 6.75% of people in CA with a Bachelors Degree have no income
# 6.17% of people in CA without a Bachelor's Degree are making over $75,000
# 18.29% of people in CA without a Bachelor's Degree are making over $75,000
