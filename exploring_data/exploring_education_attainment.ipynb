# %%
# %matplotlib notebook
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# filepaths
edattain_income = "../Resources/ca-educational-attainment-personal-income-2008-2014.csv"

# %%
#dataframes
edattain_income_df = pd.read_csv(edattain_income, encoding="utf-8")


edattain_income_df
# Out:
#                         Year        Age  Gender       Educational Attainment  \
# 0     01/01/2008 12:00:00 AM   00 to 17    Male            Children under 15
# 1     01/01/2008 12:00:00 AM   00 to 17    Male       No high school diploma
# 2     01/01/2008 12:00:00 AM   00 to 17    Male       No high school diploma
# 3     01/01/2008 12:00:00 AM   00 to 17    Male       No high school diploma
# 4     01/01/2008 12:00:00 AM   00 to 17    Male       No high school diploma
# ...                      ...        ...     ...                          ...
# 1055  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
# 1056  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
# 1057  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
# 1058  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
# 1059  01/01/2014 12:00:00 AM  65 to 80+  Female  Bachelor's degree or higher
#
#          Personal Income  Population Count
# ...

# %%
# clean out age

over_17 = edattain_income_df[edattain_income_df.Age != '00 to 17']
over_17['Year']


temp_list = []
hs_list = []
#some_college = []
#bachelors = []
#create list of population of people with high school diploma and make 5000 to 10000 dollars
for row in over_17.iterrows():
    if (row[1][0] == '01/01/2014 12:00:00 AM') and (row[1][3] == 'No high school diploma') and (row[1][4] == '$5,000 to $9,999'):
        
        temp_list.append(row[1][5])
        total = sum(temp_list)
temp_list = []
hs_list.append(total)
        
hs_list
# Out:
# [597039.0]

# %%
# create list of no high school for each personal income
no_hs = []
no_income_2014 = over_17.loc[(over_17['Personal Income'] == 'No Income') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$10,000 to $14,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$15,000 to $24,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$25,000 to $34,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$35,000 to $49,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$50,000 to $74,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
no_hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == 'No high school diploma') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
no_hs.append(no_income_2014['Population Count'].sum())


no_hs
# Out:
# [1204529.0,
#  597039.0,
#  664607.0,
#  875498.0,
#  464564.0,
#  260579.0,
#  132516.0,
#  597039.0]

# %%
#create a list of high school education by income
hs = []
no_income_2014 = over_17.loc[(over_17['Personal Income'] == 'No Income') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$10,000 to $14,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$15,000 to $24,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$25,000 to $34,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$35,000 to $49,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$50,000 to $74,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
hs.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == 'High school or equivalent') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
hs.append(no_income_2014['Population Count'].sum())


hs
# Out:
# [1161873.0,
#  626499.0,
#  692661.0,
#  1252377.0,
#  929218.0,
#  782804.0,
#  525517.0,
#  626499.0]

# %%
#list of some college by income
some_col = []
no_income_2014 = over_17.loc[(over_17['Personal Income'] == 'No Income') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$10,000 to $14,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$15,000 to $24,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$25,000 to $34,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$35,000 to $49,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$50,000 to $74,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
some_col.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == 'Some college, less than 4-yr degree') &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
some_col.append(no_income_2014['Population Count'].sum())


some_col
# Out:
# [985011.0,
#  810641.0,
#  798596.0,
#  1345257.0,
#  1091642.0,
#  1112421.0,
#  883826.0,
#  810641.0]

# %%
#create list of bachelors degree by income
bach = []
no_income_2014 = over_17.loc[(over_17['Personal Income'] == 'No Income') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$10,000 to $14,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$15,000 to $24,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$25,000 to $34,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$35,000 to $49,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$50,000 to $74,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
bach.append(no_income_2014['Population Count'].sum())

no_income_2014 = over_17.loc[(over_17['Personal Income'] == '$5,000 to $9,999') & 
            (over_17['Educational Attainment'] == "Bachelor's degree or higher") &
            (over_17['Year'] == '01/01/2014 12:00:00 AM') ]
bach.append(no_income_2014['Population Count'].sum())


bach
# Out:
# [575491.0,
#  326020.0,
#  452449.0,
#  773684.0,
#  693884.0,
#  1122791.0,
#  1594681.0,
#  326020.0]

# %%
#practice code



labels = ['No Income', '$5,000 to $9,999','$10,000 to $14,999', 
          '$15,000 to $24,999', '$25,000 to $34,999', '$35,000 to $49,999', 
          '$50,000 to $74,999','$75,000 and over']


x = np.arange(len(labels))  # the label locations
width = 0.40  # the width of the bars


fig, ax = plt.subplots()
rects1 = ax.bar(x - .3, no_hs, .2, label='No High School Diploma')
rects2 = ax.bar(x - .1, hs, .2, label='High School or Equivalent')
rects3 = ax.bar(x + .1, some_col, .2, label='Some College')
rects4 = ax.bar(x + .3, bach, .2, label="Bachelor's Degree or Higher")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Population')
ax.set_title('Population of CA by Education and Income in 2014')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='lower left', fontsize='xx-small')
plt.xticks(rotation=90)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', rotation = '90',fontsize='xx-small')


autolabel(rects1,)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

#axes.set_ylim([0,1800000])
fig.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# does graduating college actually give you more money.  statistical analysis
#does graduating
