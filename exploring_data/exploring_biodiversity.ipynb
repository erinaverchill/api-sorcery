# %%
import pandas as pd

# %%
biodiversity = "Resources/Species_Biodiversity__ACE_[ds2769].csv"

# %%
biodiversity_df = pd.read_csv(biodiversity)
biodiversity_df
# Out:
#         OBJECTID  Hex_ID         HUC12  \
# 0           1001   10486  180101050501
# 1           1002   10487  180101050601
# 2           1003   10487  180101050303
# 3           1004   10487  180101050501
# 4           1005   10488  180101050301
# ...          ...     ...           ...
# 121896    120996    9550  180201520203
# 121897    120997    9551  180201520202
# 121898    120998    9551  180201520203
# 121899    120999    9552  180201520302
# 121900    121000    9552  180201520202
#
#                                             Name  SpBioRnkEco  SpBioWtEco  \
# 0                          Basin Creek-Eel River            1    0.287096
# 1                            Upper Larabee Creek            1    0.239777
# 2                      Conley Creek-Dobbyn Creek            1    0.242514
# 3                          Basin Creek-Eel River            1    0.308519
# 4                             North Dobbyn Creek            1    0.272903
# ...
