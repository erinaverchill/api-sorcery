# %%
import pandas as pd

# %%
dispatch = "Resources/dispatch_santa_ana.csv"
crime = "Resources/santa_ana_crime.csv"

# %%
dispatch_df = pd.read_csv(dispatch)
dispatch_df
crime_df = pd.read_csv(crime)
crime_df
# Out:
#     Year  Month FirstOfMonth  Population  Murder  Manslaughter  Rape  \
# 0   2019      1     1/1/2019      338247       2             0    17
# 1   2018     12    12/1/2018      338247       1             0    19
# 2   2018     11    11/1/2018      338247       4             0    36
# 3   2018     10    10/1/2018      338247       1             0    35
# 4   2018      9     9/1/2018      338247       1             1    18
# 5   2018      8     8/1/2018      338247       3             0    24
# 6   2018      7     7/1/2018      338247       1             0    14
# 7   2018      6     6/1/2018      338247       1             0     9
# 8   2018      5     5/1/2018      338247       3             0    13
# 9   2018      4     4/1/2018      342930       1             0    12
# 10  2018      3     3/1/2018      342930       1             0    17
# 11  2018      2     2/1/2018      342930       1             0    13
# 12  2018      1     1/1/2018      342930       3             0    11
# ...

# %%
#ideas
#time of day that most incidents occur
#what type of incidents occur most often
#heatmap of locations of incidents
#
