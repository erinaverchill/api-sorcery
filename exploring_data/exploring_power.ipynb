# %%
import pandas as pd

# %%
hydro_power = 'Resources/hydro_list.csv'
elec_county = "Resources/ElectricityByCounty.csv"

# %%
hydro_power_df = pd.read_csv(hydro_power)
hydro_power_df
tot_hydro_powerhydro_power_df['ONLINE_MW'].sum()
# Out:
# 13954.291000000001

# %%
elec_county_df = pd.read_csv(elec_county)
elec_county_df
# Out:
#       County           Sector          2018          2017          2016  \
# 0    ALAMEDA  Non-Residential   7465.239633   8108.827570   7891.021676
# 1    ALAMEDA      Residential   2951.870114   2997.541830   2923.672818
# 2    ALAMEDA            Total  10417.109747  11106.369400  10814.694495
# 3     ALPINE  Non-Residential      9.283298      9.025215      8.124741
# 4     ALPINE      Residential      9.420910      9.951697      9.290913
# ..       ...              ...           ...           ...           ...
# 169     YOLO      Residential    514.741442    537.954244    508.110689
# 170     YOLO            Total   1718.062788   1745.242606   1705.442413
# 171     YUBA  Non-Residential    284.902029    277.207183    267.674821
# 172     YUBA      Residential    220.066702    229.260629    215.090257
# 173     YUBA            Total    504.968731    506.467811    482.765078
#
#              2015          2014          2013          2012          2011  \
# ...
